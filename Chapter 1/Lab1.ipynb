# %% [markdown]
# # I would like to preface that I have never used Python before this class, so I am very new to this language. I managed to do everything required to some extent. However, I am quite certain most of this relies much more on hardcoding then what you were probably looking for. Nonetheless, I did the best I could to meet the requirements for the assignment. Just know that this is not nearly as clean as I would like for it to be.

# %% [markdown]
# # Imports and displays dataframe

# %%
import openpyxl
import pandas as pd
import numpy as np
pd.read_excel('Film_Awards.xlsx', engine="openpyxl")
# Out:
#     Best Picture          Unnamed: 1  \
# 0           Year       Academy Award
# 1           2019            Parasite
# 2           2018          Green Book
# 3           2017  The Shape of Water
# 4            NaN                 NaN
# 5            NaN                 NaN
# 6     Best Actor                 NaN
# 7           Year       Academy Award
# 8           2019     Joaquin Phoenix
# 9           2018          Rami Malek
# 10          2017         Gary Oldman
# 11           NaN                 NaN
# 12           NaN                 NaN
# 13  Best Actress                 NaN
# 14          Year       Academy Award
# 15          2019     Renée Zellweger
# 16          2018       Olivia Colman
# 17          2017   Frances McDormand
#
#                                    Unnamed: 2  \
# 0                                    Director
# 1                                Bong Joon-ho
# 2                              Peter Farrelly
# 3                          Guillermo del Toro
# ...

# %% [markdown]
# # Stores dataframe as a variable to make it easier to call

# %%
data = pd.read_excel('Film_Awards.xlsx', engine='openpyxl')

# %% [markdown]
# # Sets all the information to the same dtype. (Makes 1917 an object and not an integer)

# %%
convert_dict = {
    'Best Picture' : str,
    'Unnamed: 1' :  str,
    'Unnamed: 2' : str,
    'Unnamed: 3': str,
    'Unnamed: 4': str,
    'Unnamed: 5': str,
    'Unnamed: 6': str}
data = data.astype(convert_dict)
print(data.dtypes)
# Out:
# Best Picture    object
# Unnamed: 1      object
# Unnamed: 2      object
# Unnamed: 3      object
# Unnamed: 4      object
# Unnamed: 5      object
# Unnamed: 6      object
# dtype: object

# %% [markdown]
# # Fixes typos and column discrepencies

# %%
data.at[16,'Unnamed: 6']='The Favourite'
data.at[16, 'Unnamed: 5']='Olivia Colman'
data.at[0, 'Unnamed: 2']='Film'
data.at[1, 'Unnamed: 2']='Parasite'
data.at[1, 'Unnamed: 1']='Bong Joon-ho'
data.at[2,'Unnamed: 2']='Green Book'
data.at[2, 'Unnamed: 1']='Peter Farrelly'
data.at[3, 'Unnamed: 2']='The Shape of Water'
data.at[3, 'Unnamed: 1']='Guillermo del Toro'
data.at[0, 'Unnamed: 4']='Film'
data.at[1, 'Unnamed: 4'] = '1917'
data.at[2, 'Unnamed: 4'] = 'Bohemian Rhapsody'
data.at[3, 'Unnamed: 4'] = 'Three Billboards Outside Ebbing, Missouri'
data.at[1, 'Unnamed: 3'] = 'Sam Mendes'
data.at[2, 'Unnamed: 3']='Bryan Singer'
data.at[3,'Unnamed: 3']='Martin McDonagh'
data.at[0, 'Unnamed: 6'] = 'Film'
data.at[1, 'Unnamed: 5']= 'Quentin Tarantino'
data.at[2, 'Unnamed: 5']= 'Peter Farrelly'
data.at[3, 'Unnamed: 5']= 'Greta Gerwig'
data.at[1, 'Unnamed: 6']='Once Upon a Time in Hollywood'
data.at[2, 'Unnamed: 6']='Green Book'
data.at[3, 'Unnamed: 6']='Lady Bird'

# %%
data
# Out:
#     Best Picture          Unnamed: 1  \
# 0           Year       Academy Award
# 1           2019        Bong Joon-ho
# 2           2018      Peter Farrelly
# 3           2017  Guillermo del Toro
# 4            nan                 nan
# 5            nan                 nan
# 6     Best Actor                 nan
# 7           Year       Academy Award
# 8           2019     Joaquin Phoenix
# 9           2018          Rami Malek
# 10          2017         Gary Oldman
# 11           nan                 nan
# 12           nan                 nan
# 13  Best Actress                 nan
# 14          Year       Academy Award
# 15          2019     Renée Zellweger
# 16          2018       Olivia Colman
# 17          2017   Frances McDormand
#
#                                    Unnamed: 2            Unnamed: 3  \
# 0                                        Film  Golden Globe - Drama
# 1                                    Parasite            Sam Mendes
# ...

# %% [markdown]
# # Drop repetitive or unneccessary rows

# %%
data = data.drop(index=[4, 5, 7, 11, 12, 14])

# %%
data
# Out:
#     Best Picture          Unnamed: 1  \
# 0           Year       Academy Award
# 1           2019        Bong Joon-ho
# 2           2018      Peter Farrelly
# 3           2017  Guillermo del Toro
# 6     Best Actor                 nan
# 8           2019     Joaquin Phoenix
# 9           2018          Rami Malek
# 10          2017         Gary Oldman
# 13  Best Actress                 nan
# 15          2019     Renée Zellweger
# 16          2018       Olivia Colman
# 17          2017   Frances McDormand
#
#                                    Unnamed: 2            Unnamed: 3  \
# 0                                        Film  Golden Globe - Drama
# 1                                    Parasite            Sam Mendes
# 2                                  Green Book          Bryan Singer
# 3                          The Shape of Water       Martin McDonagh
# 6                                         nan                   nan
# ...

# %% [markdown]
# # For each film involved in multiple awards, list the award and year it is associated with (This was the best I could figure out how to do. I don't know how to drop the extras that appear without dropping the entire column)

# %%
multi_award_film = data[(data['Unnamed: 2']=='Film')
 |   (data['Unnamed: 2']=='Green Book')
 | (data['Unnamed: 2']=='Joker')
 | (data['Unnamed: 2']=='Bohemian Rhapsody')
 | (data['Unnamed: 2']=='Darkest Hour')
 | (data['Unnamed: 2']=='Judy')
 | (data['Unnamed: 2']=='Three Billboards Outside Ebbing, Missouri')
 | (data['Unnamed: 6']=='Lady Bird')]
multi_award_film
# Out:
#    Best Picture          Unnamed: 1  \
# 0          Year       Academy Award
# 2          2018      Peter Farrelly
# 3          2017  Guillermo del Toro
# 8          2019     Joaquin Phoenix
# 9          2018          Rami Malek
# 10         2017         Gary Oldman
# 15         2019     Renée Zellweger
# 17         2017   Frances McDormand
#
#                                    Unnamed: 2            Unnamed: 3  \
# 0                                        Film  Golden Globe - Drama
# 2                                  Green Book          Bryan Singer
# 3                          The Shape of Water       Martin McDonagh
# 8                                       Joker       Joaquin Phoenix
# 9                           Bohemian Rhapsody            Rami Malek
# 10                               Darkest Hour           Gary Oldman
# 15                                       Judy       Renée Zellweger
# 17  Three Billboards Outside Ebbing, Missouri     Frances McDormand
#
# ...

# %% [markdown]
# # For each actor/actress winning multiple awards, list the film and award they are associated with

# %%
multi_award_actor = data[(data['Unnamed: 1']=='Joaquin Phoenix')
| (data['Unnamed: 2']=='Film')
| (data['Unnamed: 1']=='Rami Malek')
| (data['Unnamed: 1']=='Gary Oldman')
| (data['Unnamed: 1']=='Renée Zellweger')
| (data['Unnamed: 1']=='Olivia Colman')
| (data['Unnamed: 1']=='Frances Mcdommand')]
multi_award_actor
# Out:
#    Best Picture       Unnamed: 1         Unnamed: 2            Unnamed: 3  \
# 0          Year    Academy Award               Film  Golden Globe - Drama
# 8          2019  Joaquin Phoenix              Joker       Joaquin Phoenix
# 9          2018       Rami Malek  Bohemian Rhapsody            Rami Malek
# 10         2017      Gary Oldman       Darkest Hour           Gary Oldman
# 15         2019  Renée Zellweger               Judy       Renée Zellweger
# 16         2018    Olivia Colman      The Favourite           Glenn Close
#
#             Unnamed: 4                        Unnamed: 5           Unnamed: 6
# 0                 Film  Golden Globe - Musical or Comedy                 Film
# 8                Joker                     Taron Egerton            Rocketman
# 9   Bohemian Rhapsody                     Christian Bale                 Vice
# 10        Darkest Hour                      James Franco  The Disaster Artist
# ...
